# %% [markdown]
# Importing Cluster class from cluster.py

# %%
from cluster import Cluster
# Out:
# Using TensorFlow backend.

# %%
c = Cluster()

# %% [markdown]
# Loading images and extracting features

# %%
c.load_images('images')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:21<00:00,  4.71it/s]

# %% [markdown]
# Finding optimal `n_clusters` using silhouette_score

# %%
c.find_best_k()

# %% [markdown]
# Get clusters on `best_k` or custom `n_clusters`

# %%
c.run_kmeans()
# Out:
# CLUSTER: 0 --> 47 images
# CLUSTER: 1 --> 53 images

# %%
c.get_cluster(0)

# %%
c.extract_cluster(1, extraction_type='copy', to='Dogs')
